# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target']=data.target

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
df.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
corr=df.corr()
corr
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
# target                       -0.328222    0.437776 -0.049643
#
# ...

# %%
plt.imshow(corr,interpolation='None',cmap='coolwarm')
plt.xticks(range(len(corr)),corr.columns,rotation=90)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.colorbar(label='correlation coefficient')

# %%
plt.figure(figsize=(12,9))
for i,col in enumerate(df.columns):
    plt.subplot(4,4,i+1)
    plt.hist(df[col],bins=20,alpha=0.7,edgecolor='black')
    plt.title(f'{col}(skew:{df[col].skew():.2f})')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %%
df['target'].value_counts().sort_index().plot(kind='bar')
plt.xlabel("target")
plt.ylabel("value_counts")
plt.title("target counts")
# Out:
# Text(0.5, 1.0, 'target counts')

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,4,1)
plt.scatter(df['flavanoids'],df['target'],color='blue',marker="*")
plt.xlabel("flavanoids")
plt.ylabel("target")
plt.title("flavnoids vs target")
plt.subplot(1,4,2)
plt.scatter(df['total_phenols'],df['target'],color='blue',marker="*")
plt.xlabel("total phenols")
plt.ylabel("target")
plt.title("total phenols vs target")
plt.subplot(1,4,3)
plt.scatter(df['nonflavanoid_phenols'],df['target'],color='blue',marker="*")
plt.xlabel("nonflavanoids phenols")
plt.ylabel("target")
plt.title("nonflavnoids phenols vs target")
plt.subplot(1,4,4)
plt.scatter(df['alcalinity_of_ash'],df['target'],color='blue',marker="*")
plt.xlabel("alcalinity of ash")
plt.ylabel("target")
plt.title("alcalinity of ash vs target")
# Out:
# Text(0.5, 1.0, 'alcalinity of ash vs target')

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,4,1)
plt.scatter(df['proline'],df['target'],color='blue',marker="*")
plt.xlabel("proline")
plt.ylabel("target")
plt.title("proline vs target")
plt.subplot(1,4,2)
plt.scatter(df['od280/od315_of_diluted_wines'],df['target'],color='blue',marker="*")
plt.xlabel("od280/od315_of_diluted_wines")
plt.ylabel("target")
plt.title("od280/od315_of_diluted_wines vs target")
plt.subplot(1,4,3)
plt.scatter(df['hue'],df['target'],color='blue',marker="*")
plt.xlabel("hue")
plt.ylabel("target")
plt.title("hue vs target")
plt.subplot(1,4,4)
plt.scatter(df['proanthocyanins'],df['target'],color='blue',marker="*")
plt.xlabel("proanthocyanins")
plt.ylabel("target")
plt.title("proanthocyanins vs target")
# Out:
# Text(0.5, 1.0, 'proanthocyanins vs target')

# %%
plt.figure(figsize=(12, 6))
df_normalized = (df- df.mean()) / df.std()
df_normalized.boxplot()
plt.title('Box Plot - All Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.xlabel("features")
plt.show()

# %%
Q1=df['malic_acid'].quantile(0.25)
Q3=df['malic_acid'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['malic_acid'] = df['malic_acid'].clip(lower=lower_limit, upper=upper_limit)

# %%
Q1=df['ash'].quantile(0.25)
Q3=df['ash'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['ash'] = df['ash'].clip(lower=lower_limit, upper=upper_limit)

Q1=df['alcalinity_of_ash'].quantile(0.25)
Q3=df['alcalinity_of_ash'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['alcalinity_of_ash'] = df['alcalinity_of_ash'].clip(lower=lower_limit, upper=upper_limit)

Q1=df['magnesium'].quantile(0.25)
Q3=df['magnesium'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['magnesium'] = df['magnesium'].clip(lower=lower_limit, upper=upper_limit)

Q1=df['hue'].quantile(0.25)
Q3=df['hue'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['hue'] = df['hue'].clip(lower=lower_limit, upper=upper_limit)

Q1=df['color_intensity'].quantile(0.25)
Q3=df['color_intensity'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['color_intensity'] = df['color_intensity'].clip(lower=lower_limit, upper=upper_limit)

Q1=df['proanthocyanins'].quantile(0.25)
Q3=df['proanthocyanins'].quantile(0.75)
IQR=Q3-Q1
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
df['proanthocyanins'] = df['proanthocyanins'].clip(lower=lower_limit, upper=upper_limit)

# %%
plt.figure(figsize=(12, 6))
df_normalized = (df- df.mean()) / df.std()
df_normalized.boxplot()
plt.title('Box Plot - All Features')
plt.xticks(rotation=45)
plt.tight_layout()
plt.xlabel("features")
plt.show()

# %%
df.skew()
# Out:
# alcohol                        -0.051482
# malic_acid                      0.969169
# ash                            -0.149764
# alcalinity_of_ash               0.114798
# magnesium                       0.670809
# total_phenols                   0.086639
# flavanoids                      0.025344
# nonflavanoid_phenols            0.450151
# proanthocyanins                 0.350811
# color_intensity                 0.735453
# hue                            -0.034190
# od280/od315_of_diluted_wines   -0.307285
# proline                         0.767822
# target                          0.107431
# dtype: float64

# %%
skewed_features = ['nonflavanoid_phenols','color_intensity','magnesium','malic_acid','proline']
for feature in skewed_features:
    df[f'{feature}'] = np.log1p(df[feature])

# %%
df.skew()
# Out:
# alcohol                        -0.051482
# malic_acid                      0.500235
# ash                            -0.149764
# alcalinity_of_ash               0.114798
# magnesium                       0.357963
# total_phenols                   0.086639
# flavanoids                      0.025344
# nonflavanoid_phenols            0.293697
# proanthocyanins                 0.350811
# color_intensity                 0.051725
# hue                            -0.034190
# od280/od315_of_diluted_wines   -0.307285
# proline                         0.087930
# target                          0.107431
# dtype: float64

# %%
plt.figure(figsize=(12,9))
for i,col in enumerate(df.columns):
    plt.subplot(4,4,i+1)
    plt.hist(df[col],bins=20,alpha=0.7,edgecolor='black')
    plt.title(f'{col}(skew:{df[col].skew():.2f})')
    plt.xlabel(col)
plt.tight_layout()
plt.show()

# %%
x=df.drop(columns=['target'])
y=df['target']

# %%
x.head(2)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23    0.996949  2.43               15.6   4.852030           2.80
# 1    13.20    1.022451  2.14               11.2   4.615121           2.65
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06              0.246860             2.29         1.893112  1.04
# 1        2.76              0.231112             1.28         1.682688  1.05
#
#    od280/od315_of_diluted_wines   proline
# 0                          3.92  6.971669
# 1                          3.40  6.957497

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,stratify=y)

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.9202387454903276

# %%
y_predict=reg.predict(x_test)
y_predict
# Out:
# array([ 1.00989467,  0.01834119,  1.36832305,  1.59844201,  1.1465937 ,
#         0.69911311,  1.78671373,  0.96592235,  1.09707491,  1.83519898,
#         0.25037037,  2.2711785 ,  0.36874356,  0.02983281,  0.15100715,
#         1.16308804, -0.069562  ,  1.76974991])

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_predict)
print(f"Mean Absolute Error: ${mae:,.2f}")
# Out:
# Mean Absolute Error: $0.18

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_predict)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.04849681215557243

# %%
rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: ${rmse:,.2f}")
# Out:
# Root Mean Squared Error: $0.22

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_predict, color='teal', alpha=0.6, edgecolors='k')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', linewidth=2)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.grid(True)
plt.tight_layout()

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# c:\Users\Asus\OneDrive\Desktop\data science\my_project\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([1, 0, 1, 2, 1, 1, 2, 1, 1, 2, 0, 2, 0, 0, 0, 1, 0, 2])

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_predict)

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_predict)
print(f"Mean Absolute Error: ${mae:,.2f}")
# Out:
# Mean Absolute Error: $0.00

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True)
plt.xlabel("predicted")
plt.ylabel("truth")
# Out:
# Text(95.72222222222221, 0.5, 'truth')

# %%
model=tree.DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict=model.predict(x_test)
y_predict
# Out:
# array([1, 0, 1, 1, 1, 1, 2, 1, 1, 2, 0, 2, 0, 0, 0, 1, 0, 2])

# %%
model.score(x_test,y_test)
# Out:
# 0.9444444444444444

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 10))
plot_tree(
    model,
    feature_names=data.feature_names,    
    class_names=data.target_names,         
    filled=True,                        
    rounded=True,                         
    fontsize=10                            
)

plt.title("Decision Tree for Wine Classification")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier()
}

for name, model in models.items():
    model.fit(x_train_scaled, y_train)
    y_pred = model.predict(x_test_scaled)
    acc = model.score(x_test_scaled, y_test)
    print(f"\n{name} Accuracy: {acc:.4f}")
    print(f"{name} Classification Report:\n{classification_report(y_test, y_pred)}")

    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_test, y_pred)

    plt.figure(figsize=(5,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False)
    plt.title(f'Confusion Matrix: {name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
# Out:
# Logistic Regression Accuracy: 1.0000
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
# Random Forest Accuracy: 1.0000
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00         5
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
# SVM Accuracy: 1.0000
# SVM Classification Report:
# ...
